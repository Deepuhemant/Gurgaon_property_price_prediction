# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
flats.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'price_in_crores',
#        'price_per_sqft', 'area_sqft', 'areaWithType', 'bedRoom', 'bathroom',
#        'balcony', 'additionalRoom', 'address', 'floorNum', 'facing',
#        'agePossession', 'nearbyLocations', 'description', 'furnishDetails',
#        'features', 'rating'],
#       dtype='object')

# %%
houses.columns
# Out:
# Index(['property_name', 'property_type', 'price_in_crores', 'price_per_sqft',
#        'bedRoom', 'bathroom', 'balcony', 'additionalRoom', 'address',
#        'noOfFloor', 'facing', 'agePossession', 'nearbyLocations',
#        'description', 'furnishDetails', 'features', 'rating', 'society',
#        'Plot Area', 'Built-up Area', 'Carpet Area', 'area_in_sqft'],
#       dtype='object')

# %%
df = pd.concat([flats,houses])

# %%
df.to_csv('gurgaon_properties.csv', index=False)

# %%
flats['floorNum'].isnull().sum()
# Out:
# 2

# %%
houses['noOfFloor'].isnull().sum()
# Out:
# 19

# %%
flats['area_sqft'].isnull().sum()
# Out:
# 1

# %%
houses['area_in_sqft'].isnull().sum()
# Out:
# 19
