# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gurgaonpropertyfeatureselection.csv')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    property_type  sector  bedRoom  bathroom  balcony  agePossession  \
# 0            0.0    72.0      2.0       2.0      1.0            3.0
# 1            0.0    34.0      2.0       2.0      1.0            2.0
# 2            0.0   100.0      2.0       2.0      3.0            1.0
# 3            0.0    64.0      2.0       2.0      2.0            1.0
# 4            0.0    95.0      2.0       2.0      3.0            4.0
#
#    Built Up area  store room  servant room  furnishing_type  luxury_category  \
# 0         1000.0           0             0                1              1.0
# 1          722.0           0             0                0              1.0
# 2          661.0           0             0                1              1.0
# 3         1333.0           0             0                1              2.0
# 4         1217.0           0             0                1              1.0
#
#    floor_category  price_in_crores
# 0             2.0             0.45
# 1             1.0             0.50
# 2             0.0             0.40
# 3             1.0             1.47
# 4             2.0             0.70

# %%
x = df.drop('price_in_crores', axis=1)
y = df['price_in_crores']

# %%
x.head()
# Out:
#    property_type  sector  bedRoom  bathroom  balcony  agePossession  \
# 0            0.0    72.0      2.0       2.0      1.0            3.0
# 1            0.0    34.0      2.0       2.0      1.0            2.0
# 2            0.0   100.0      2.0       2.0      3.0            1.0
# 3            0.0    64.0      2.0       2.0      2.0            1.0
# 4            0.0    95.0      2.0       2.0      3.0            4.0
#
#    Built Up area  store room  servant room  furnishing_type  luxury_category  \
# 0         1000.0           0             0                1              1.0
# 1          722.0           0             0                0              1.0
# 2          661.0           0             0                1              1.0
# 3         1333.0           0             0                1              2.0
# 4         1217.0           0             0                1              1.0
#
#    floor_category
# 0             2.0
# 1             1.0
# 2             0.0
# 3             1.0
# 4             2.0

# %%
y.head()
# Out:
# 0    0.45
# 1    0.50
# 2    0.40
# 3    1.47
# 4    0.70
# Name: price_in_crores, dtype: float64

# %%
## Applying the log1p transformation to the target variable

y_transformed = np.log1p(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y_transformed, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

# %%
columns_to_encode = ['sector','balcony','agePossession','furnishing_type','luxury_category','floor_category']

# %%
# Creating a column transformer for preprocessing

preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['property_type','bedRoom','bathroom','Built Up area','servant room','store room']),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), columns_to_encode)

    ], remainder='passthrough'
)

# %%
# Creating a pipeline

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', SVR())
])

# %%
# k-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X_train, y_train, cv=kfold, scoring='r2')
# Out:
# C:\Users\deepu\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean()
# Out:
# np.float64(0.8734215595588424)

# %%
scores.std()
# Out:
# np.float64(0.019855118464938884)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['property_type', 'bedRoom',
#                                                    'bathroom', 'Built Up area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'balcony',
#                                                    'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', SVR())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
y_pred
# Out:
# array([ 3.23617047,  1.15357456,  0.56183399,  1.73918769,  1.5979483 ,
#         0.68954145,  3.16629875,  1.91858137,  1.57518576,  3.53067986,
#         1.52597449,  1.98347548,  0.77310961,  0.83588221,  1.19843493,
#         8.98083664,  2.86312376,  2.08142089,  0.64767972,  1.35082059,
#         2.166494  ,  0.28642794,  6.12570604,  5.88533042,  0.39473945,
#         0.79390465,  1.93041748,  1.11081159,  0.97208289,  1.66518715,
#         0.76102625,  0.42318573,  4.54475206,  6.3286906 ,  1.49842387,
#         2.07724374,  1.05813224,  3.66279811,  5.01447352,  2.01334249,
#        12.90975645, 10.02505438,  6.84769747,  2.36388215,  2.79925883,
#         0.94045901,  1.80148376,  5.76651923,  1.58233059,  0.87670555,
#         0.6580732 ,  2.8233214 ,  2.05677588,  1.78871819,  5.25984268,
#         1.35834469,  0.74034333,  1.70125594,  1.0922522 , 11.43551587,
#        14.04998336,  4.41104176,  1.54154888,  2.43102773,  2.96401388,
#         1.68812326,  7.82900069,  2.06673111,  2.61686702,  1.92632455,
#         5.39937821,  1.06375708,  0.60416536,  0.77025983,  1.20275706,
#         3.43062406,  1.78520008,  2.12089875,  1.28866691,  0.68793859,
#         1.08845892,  2.00044185,  9.32535479,  0.72603314,  1.28471898,
#         4.16598081,  0.49138593,  2.61005105,  2.89049417,  3.29700972,
#         1.70427492,  0.46127269,  3.5925165 ,  0.91885138,  1.07500075,
#         1.42302453,  6.61732434,  2.79944463,  4.96473587,  1.13862564,
#         3.56461703,  1.96632756,  1.33523369,  1.10215785,  0.53148035,
#         3.61791631,  2.80661303,  1.97953897,  1.46940209,  1.09953032,
#         0.63296247,  6.11530868,  1.48089339,  0.3495033 ,  0.76507663,
#         1.58639677,  4.09934796,  1.7684453 ,  0.89946965,  0.98055764,
#         5.85821965,  6.2298696 ,  1.98921902,  4.54087912,  2.35110643,
#         1.83643267,  1.07130197,  1.46709858,  1.29585711,  1.77266416,
#         1.63470671,  1.48374587,  0.3748476 ,  1.57718197,  1.59705853,
#         0.79516413,  1.98582946,  0.69655393,  0.70722287,  1.35893707,
#         1.42249173,  0.72513256,  0.76052859,  0.67702698,  0.7380286 ,
#         1.61807202,  2.29706236,  1.41684134,  1.39121822,  0.73896446,
#         0.73781616,  2.20294501,  1.663271  ,  1.05582936,  5.42205677,
